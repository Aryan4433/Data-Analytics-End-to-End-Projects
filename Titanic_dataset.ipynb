# %%
import pandas as pd
import numpy as np

# %%
# D={}
# for i in range(3):
#     a=input("Enter column names:")
#     b=input().split()
#     D[a]=b
# pd.DataFrame(D)

# %%
df=pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # DATA PREPROCESSING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include=object)
# Out:
#                                                  Name   Sex Ticket    Cabin  \
# count                                             891   891    891      204
# unique                                            891     2    681      147
# top     Graham, Mrs. William Thompson (Edith Junkins)  male   1601  B96 B98
# freq                                                1   577      7        4
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*(100)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# clearing the data

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
# drop Cabin data because it have move than 50 % nan values
df.drop(columns=['Cabin'],inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
# now clear others nan values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].median()
# Out:
# 28.0

# %%
# if there is less diff in mean and median then fill data with mean()
# if there is high diff in mean and median then fill data with median()
# now fill

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
# As you can see nan will be fixed

# %%
df['Embarked'].mode()
# Out:
# 0    S
# dtype: object

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Now as you see your data has been clear now!!!

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
# TELL HOW MANY SURVIVED in %

df['Survived'].value_counts()/df.shape[0]*(100)
# Out:
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %%
# Tell how many people travels in each class

df['Pclass'].value_counts()/df.shape[0]*(100)
# Out:
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: Pclass, dtype: float64

# %%
# Tell how many people are male or female

df['Sex'].value_counts()/df.shape[0]*(100)
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64

# %%
# find data where age is max and Fare is max

df['Age'].max()
# Out:
# 80.0

# %%
df['Fare'].max()
# Out:
# 512.3292

# %%
df[(df['Age']==max(df['Age']))  | (df['Fare']==max(df['Fare']))]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 258          259         1       1                      Ward, Miss. Anna
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 679          680         1       1    Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Embarked
# 258  female  35.0      0      0  PC 17755  512.3292        C
# 630    male  80.0      0      0     27042   30.0000        S
# 679    male  36.0      0      1  PC 17755  512.3292        C
# 737    male  35.0      0      0  PC 17755  512.3292        C

# %%
# find data where age is min and Fare is min

df['Fare'].min()
# Out:
# 0.0

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df[(df['Age']==min(df['Age']))  | (df['Fare']==min(df['Fare']))]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
df.set_index("PassengerId", inplace=True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
# find where age is greater than 35 and fare is greater than 100

df[(df['Age']>35) & (df['Fare']>100)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 196                 1       1
# 269                 1       1
# 300                 1       1
# 320                 1       1
# 326                 1       1
# 333                 0       1
# 338                 1       1
# 381                 1       1
# 391                 1       1
# 439                 0       1
# 545                 0       1
# 582                 1       1
# 610                 1       1
# 660                 0       1
# 661                 1       1
# 680                 1       1
# 699                 0       1
# 717                 1       1
# 764                 1       1
# 780                 1       1
# 857                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 196                                       Lurette, Miss. Elise  female  58.0
# 269              Graham, Mrs. William Thompson (Edith Junkins)  female  58.0
# ...

# %%
# Tell the mean min mac sum count od sex and fair using aggregation

df.groupby(['Sex'])['Fare'].agg(['mean','min','max','sum','count'])
# Out:
#              mean   min       max         sum  count
# Sex
# female  44.479818  6.75  512.3292  13966.6628    314
# male    25.523893  0.00  512.3292  14727.2865    577

# %%
# Tell that how many male and female survived in titanic

df.groupby(['Pclass','Sex'])['Survived'].value_counts()
# Out:
# Pclass  Sex     Survived
# 1       female  1            91
#                 0             3
#         male    0            77
#                 1            45
# 2       female  1            70
#                 0             6
#         male    0            91
#                 1            17
# 3       female  0            72
#                 1            72
#         male    0           300
#                 1            47
# Name: Survived, dtype: int64

# %% [markdown]
# # Feature Enginerrring

# %%
# ADD sipsb and parch columns into single family

df['Family']= df['SibSp']+df['Parch']

# %%
df.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#              Parch     Ticket  Fare Embarked  Family
# PassengerId
# 1                0  A/5 21171  7.25        S       1

# %%
df.drop(columns=['SibSp','Parch'],inplace = True)

# %%
df.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age     Ticket  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0  A/5 21171
#
#              Fare Embarked  Family
# PassengerId
# 1            7.25        S       1

# %%
col=list(df.columns)
col
# Out:
# ['Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'Ticket',
#  'Fare',
#  'Embarked',
#  'Family']

# %%
df[col[0:5]+[col[-1]]+col[5:8]]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...
