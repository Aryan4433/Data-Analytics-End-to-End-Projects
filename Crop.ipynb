# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("apy_2 .csv")

# %%
df
# Out:
#        Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0               0       Karnataka         UDUPI       2005  Rabi
# 1               1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2               2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3               3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4               4   Uttar Pradesh     SULTANPUR       2011  Rabi
# ...           ...             ...           ...        ...          ...
# 73822       73822   Uttar Pradesh     SULTANPUR       2001  Rabi
# 73823       73823    Chhattisgarh          DURG       2014  Rabi
# 73824       73824   Uttar Pradesh    RAE BARELI       2010  Summer
# 73825       73825           Assam        KAMRUP       1998  Rabi
# 73826       73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 0             Horse-gram    1122.0       836.0
# 1                Brinjal     194.0         0.0
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73827 entries, 0 to 73826
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     73827 non-null  int64
#  1   State_Name     73827 non-null  object
#  2   District_Name  73827 non-null  object
#  3   Crop_Year      73827 non-null  int64
#  4   Season         73827 non-null  object
#  5   Crop           73827 non-null  object
#  6   Area           73827 non-null  float64
#  7   Production     72679 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0     Crop_Year          Area    Production
# count  73827.000000  73827.000000  7.382700e+04  7.267900e+04
# mean   36913.000000   2005.618134  1.186849e+04  4.426138e+05
# std    21312.163499      4.957966  4.884827e+04  1.346706e+07
# min        0.000000   1997.000000  5.000000e-02  0.000000e+00
# 25%    18456.500000   2002.000000  7.900000e+01  8.600000e+01
# 50%    36913.000000   2006.000000  5.730000e+02  7.240000e+02
# 75%    55369.500000   2010.000000  4.335000e+03  6.900000e+03
# max    73826.000000   2015.000000  4.205800e+06  1.001000e+09

# %%
df.describe(include=object)
# Out:
#            State_Name District_Name       Season   Crop
# count           73827         73827        73827  73827
# unique             33           645            6    122
# top     Uttar Pradesh    AURANGABAD  Kharif        Rice
# freq            10100           291        28750   4541

# %%
df.describe(include=float)
# Out:
#                Area    Production
# count  7.382700e+04  7.267900e+04
# mean   1.186849e+04  4.426138e+05
# std    4.884827e+04  1.346706e+07
# min    5.000000e-02  0.000000e+00
# 25%    7.900000e+01  8.600000e+01
# 50%    5.730000e+02  7.240000e+02
# 75%    4.335000e+03  6.900000e+03
# max    4.205800e+06  1.001000e+09

# %%
df.shape
# Out:
# (73827, 8)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       1148
# dtype: int64

# %%
a=df[df['Production']==0.0]
a
# Out:
#        Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 1               1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 134           134      Tamil Nadu       MADURAI       2002  Whole Year
# 136           136       Rajasthan          TONK       2002  Whole Year
# 162           162         Haryana       JHAJJAR       2002  Whole Year
# 188           188  Madhya Pradesh   NARSINGHPUR       2003  Whole Year
# ...           ...             ...           ...        ...          ...
# 73503       73503  Madhya Pradesh         SATNA       2003  Whole Year
# 73528       73528  Madhya Pradesh      SHAJAPUR       2002  Whole Year
# 73636       73636     Maharashtra       SOLAPUR       1999  Kharif
# 73665       73665     Maharashtra    AHMEDNAGAR       2003  Rabi
# 73707       73707  Madhya Pradesh         SIDHI       1999  Kharif
#
#                      Crop    Area  Production
# 1                 Brinjal   194.0         0.0
# ...

# %%
df.dropna(subset=['Production'], inplace = True)

# %%
df.shape
# Out:
# (72679, 8)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0           0       Karnataka         UDUPI       2005  Rabi
# 1           1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2           2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3           3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4           4   Uttar Pradesh     SULTANPUR       2011  Rabi
#
#          Crop    Area  Production
# 0  Horse-gram  1122.0       836.0
# 1     Brinjal   194.0         0.0
# 2     Sesamum   334.0       118.0
# 3      Tomato   538.0      7289.0
# 4   Coriander    59.0        33.0

# %% [markdown]
# # Which of these crops are produced during the Summer season?

# %%
a=df.groupby(['Season'])['Crop'].sum().reset_index()
a
# Out:
#         Season                                               Crop
# 0  Autumn       RiceRiceGroundnutRiceMaizeRiceRiceRiceRiceRice...
# 1  Kharif       Niger seedGroundnutGroundnutPeas & beans (Puls...
# 2  Rabi         Horse-gramSesamumTomatoCorianderBlack pepperRa...
# 3  Summer       GroundnutMaizeRiceRiceSesamumWheatRiceGroundnu...
# 4  Whole Year   BrinjalOnionPotatoOnionTurmericSweet potatoSun...
# 5  Winter       Horse-gramRiceHorse-gramHorse-gramRapeseed &Mu...

# %%
a.iloc[3,1]
# Out:
# 'GroundnutMaizeRiceRiceSesamumWheatRiceGroundnutOnionUradRiceMaizeUradRiceMaizePeas & beans (Pulses)MaizeSunflowerRagiSesamumBajraMaizeMaizeMoong(Green Gram)RiceCotton(lint)UradMaizeMoong(Green Gram)UradUradMoong(Green Gram)JowarSunflowerUradRiceGroundnutOnionSunflowerCowpea(Lobia)MaizeRiceSesamumRiceTobaccoSunflowerRagiSunflowerUradUradMoong(Green Gram)UradJowarMoong(Green Gram)SunflowerOnionRiceUradMoong(Green Gram)RiceRiceRiceMaizeMaizeOnionRiceMaizeMaizeSesamumOnionSunflowerGroundnutGroundnutMaizeMaizeGroundnutGroundnutRiceMaizeMaizeJowarSesamumHorse-gramMoong(Green Gram)GroundnutRiceGroundnutRiceUradDry chilliesMoong(Green Gram)Moong(Green Gram)GroundnutRiceOnionRiceMoong(Green Gram)Dry chilliesMoong(Green Gram)JowarRiceMaizePaddyRiceMaizeRiceMaizeSunflowerOnionSunflowerMaizeMaizeHorse-gramGroundnutDry chilliesGroundnutUradMoong(Green Gram)SunflowerMaizeSunflowerMoong(Green Gram)MaizeMaizeGroundnutUradMaizeMaizeGroundnutCowpea(Lobia)Moong(Green Gram)MaizeMoong(Green Gram)RagiWhe
# ...

# %%
pd.DataFrame({a.iloc[3][0]:})
# Out:
#   File "<ipython-input-86-792e4783cc50>", line 1
#     pd.DataFrame({a.iloc[3][0]:})
#                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # During which year did Haryana have the highest crop production?

# %%
df.head()
# Out:
#    Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0           0       Karnataka         UDUPI       2005  Rabi
# 1           1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2           2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3           3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4           4   Uttar Pradesh     SULTANPUR       2011  Rabi
#
#          Crop    Area  Production
# 0  Horse-gram  1122.0       836.0
# 1     Brinjal   194.0         0.0
# 2     Sesamum   334.0       118.0
# 3      Tomato   538.0      7289.0
# 4   Coriander    59.0        33.0

# %%
a=df.groupby(['State_Name','Crop_Year'])['Production'].sum().reset_index()
a
# Out:
#                       State_Name  Crop_Year   Production
# 0    Andaman and Nicobar Islands       2000      6952.00
# 1    Andaman and Nicobar Islands       2001       301.00
# 2    Andaman and Nicobar Islands       2002     47986.62
# 3    Andaman and Nicobar Islands       2003  26660803.22
# 4    Andaman and Nicobar Islands       2004  52399240.63
# ..                           ...        ...          ...
# 513                  West Bengal       2010  11861068.00
# 514                  West Bengal       2011  11443934.00
# 515                  West Bengal       2012  16036957.00
# 516                  West Bengal       2013  12979192.00
# 517                  West Bengal       2014  17497459.00
#
# [518 rows x 3 columns]

# %%
a[a['State_Name']=="Andaman and Nicobar Islands"]
# Out:
#                     State_Name  Crop_Year   Production
# 0  Andaman and Nicobar Islands       2000      6952.00
# 1  Andaman and Nicobar Islands       2001       301.00
# 2  Andaman and Nicobar Islands       2002     47986.62
# 3  Andaman and Nicobar Islands       2003  26660803.22
# 4  Andaman and Nicobar Islands       2004  52399240.63
# 5  Andaman and Nicobar Islands       2005  26441821.13
# 6  Andaman and Nicobar Islands       2006  15407237.94
# 7  Andaman and Nicobar Islands       2010  82311554.28

# %%
a[a['State_Name']=="Haryana"]
# Out:
#     State_Name  Crop_Year  Production
# 152    Haryana       1997   3376800.0
# 153    Haryana       1998   6653600.0
# 154    Haryana       1999   7188901.0
# 155    Haryana       2000   5872800.0
# 156    Haryana       2001   7009900.0
# 157    Haryana       2002   7837700.0
# 158    Haryana       2003   8437562.0
# 159    Haryana       2004   7523400.0
# 160    Haryana       2005   9328300.0
# 161    Haryana       2006   6566600.0
# 162    Haryana       2007   7323500.0
# 163    Haryana       2008   9647100.0
# 164    Haryana       2009   5214480.0
# 165    Haryana       2010   5548900.0
# 166    Haryana       2011   9021300.0
# 167    Haryana       2012   7996416.0

# %% [markdown]
# # The maximum and minimum area for production were in the years

# %%
df.head()
# Out:
#    Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0           0       Karnataka         UDUPI       2005  Rabi
# 1           1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2           2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3           3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4           4   Uttar Pradesh     SULTANPUR       2011  Rabi
#
#          Crop    Area  Production
# 0  Horse-gram  1122.0       836.0
# 1     Brinjal   194.0         0.0
# 2     Sesamum   334.0       118.0
# 3      Tomato   538.0      7289.0
# 4   Coriander    59.0        33.0

# %%
c=df.groupby(['Crop_Year'])['Area'].max().reset_index()
c
# Out:
#     Crop_Year       Area
# 0        1997  4205800.0
# 1        1998   545286.0
# 2        1999   699894.0
# 3        2000   636700.0
# 4        2001   483246.0
# 5        2002   672100.0
# 6        2003  1020181.0
# 7        2004   857823.0
# 8        2005   464880.0
# 9        2006   933271.0
# 10       2007   448200.0
# 11       2008   608851.0
# 12       2009   967622.0
# 13       2010   545965.0
# 14       2011   482718.0
# 15       2012   486172.0
# 16       2013   711145.0
# 17       2014   496134.0
# 18       2015   278000.0

# %%
sns.barplot(c['Crop_Year'], c['Area'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Which state in India had the second lowest crop production

# %%
df.head(2)
# Out:
#    Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0           0       Karnataka         UDUPI       2005  Rabi
# 1           1  Madhya Pradesh       GWALIOR       2003  Whole Year
#
#          Crop    Area  Production
# 0  Horse-gram  1122.0       836.0
# 1     Brinjal   194.0         0.0

# %%
d=df.groupby(['State_Name'])['Production'].sum().sort_values(ascending=False).reset_index()
d
# Out:
#                      State_Name    Production
# 0                        Kerala  2.299779e+10
# 1                Andhra Pradesh  3.141848e+09
# 2                    Tamil Nadu  1.787126e+09
# 3                 Uttar Pradesh  1.069989e+09
# 4                   West Bengal  5.327023e+08
# 5                         Assam  5.201106e+08
# 6                   Maharashtra  3.930627e+08
# 7                     Karnataka  2.637879e+08
# 8   Andaman and Nicobar Islands  2.032759e+08
# 9                        Punjab  1.724376e+08
# 10                      Gujarat  1.538659e+08
# 11                          Goa  1.421826e+08
# 12               Madhya Pradesh  1.337226e+08
# 13                   Telangana   1.202722e+08
# 14                        Bihar  1.151581e+08
# 15                      Haryana  1.145473e+08
# 16                    Rajasthan  8.671658e+07
# 17                   Puducherry  7.326832e+07
# 18                       Odisha  4.563306e+07
# ...

# %%
sns.barplot(d['State_Name'], d['Production'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # What were the top three produced crops in the year 2012?

# %%
df.head(2)
# Out:
#    Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0           0       Karnataka         UDUPI       2005  Rabi
# 1           1  Madhya Pradesh       GWALIOR       2003  Whole Year
#
#          Crop    Area  Production
# 0  Horse-gram  1122.0       836.0
# 1     Brinjal   194.0         0.0

# %%
r=df.groupby(['Crop_Year'])['Crop'].sum().reset_index()
r
# Out:
#     Crop_Year                                               Crop
# 0        1997  GroundnutCorianderBajraSugarcaneJowarSoyabeanO...
# 1        1998  RiceTapiocaJowarSunflowerBajraCotton(lint)Maiz...
# 2        1999  Rapeseed &MustardTobaccoBajraGarlicMestaJowarS...
# 3        2000  GramRiceOther  Rabi pulsesRiceCashewnutHorse-g...
# 4        2001  PotatoTurmericPotatoCastor seedWheatCorianderU...
# 5        2002  OnionSweet potatoPeas & beans (Pulses)Small mi...
# 6        2003  BrinjalOnionSugarcaneMoong(Green Gram)Sugarcan...
# 7        2004  SugarcaneSannhampSannhampDry chilliesGroundnut...
# 8        2005  Horse-gramOther Kharif pulsesUradRapeseed &Mus...
# 9        2006  Niger seedGroundnutGramMaizeBajraMaizeBlack pe...
# 10       2007  Dry chilliesMoong(Green Gram)RiceRapeseed &Mus...
# 11       2008  GroundnutKhesariMoong(Green Gram)Sweet potatoS...
# 12       2009  Horse-gramGramMasoorRapeseed &MustardHorse-gra...
# ...

# %%
r[r['Crop_Year']==2012]
# Out:
#     Crop_Year                                               Crop
# 15       2012  Rapeseed &MustardCorianderHorse-gramGramUradWh...

# %%
sns.barplot(df['Crop_Year'],df['Production'])
plt.xticks(rotation=90)
plt.show()

# %%
df[df['Crop_Year']==2012]
# Out:
#        Unnamed: 0      State_Name     District_Name  Crop_Year       Season  \
# 26             26        Nagaland           KIPHIRE       2012  Rabi
# 44             44  Madhya Pradesh       HOSHANGABAD       2012  Whole Year
# 74             74    Chhattisgarh          DHAMTARI       2012  Kharif
# 76             76     Uttarakhand  UDAM SINGH NAGAR       2012  Rabi
# 94             94      Tamil Nadu       KRISHNAGIRI       2012  Kharif
# ...           ...             ...               ...        ...          ...
# 73706       73706          Kerala            KOLLAM       2012  Whole Year
# 73724       73724   Uttar Pradesh             UNNAO       2012  Rabi
# 73769       73769       Karnataka   BENGALURU URBAN       2012  Whole Year
# 73771       73771       Meghalaya  SOUTH GARO HILLS       2012  Whole Year
# 73805       73805  Andhra Pradesh           KRISHNA       2012  Rabi
#
#                     Crop    Area  Production
# 26     Rapeseed &Mustard  1190.0      1200.0
# ...

# %%
df[df['Crop_Year']==2012].sort_values(by='Production',ascending=False).head(20)
# Out:
#        Unnamed: 0      State_Name       District_Name  Crop_Year       Season  \
# 64571       64571          Kerala            THRISSUR       2012  Whole Year
# 53633       53633          Kerala              KOLLAM       2012  Whole Year
# 21230       21230  Andhra Pradesh      VISAKHAPATANAM       2012  Whole Year
# 58436       58436          Kerala              IDUKKI       2012  Whole Year
# 22516       22516          Kerala             WAYANAD       2012  Whole Year
# 36011       36011  Andhra Pradesh             KRISHNA       2012  Whole Year
# 66074       66074   Uttar Pradesh               KHERI       2012  Kharif
# 67136       67136  Andhra Pradesh        SPSR NELLORE       2012  Whole Year
# 45321       45321   Uttar Pradesh       MUZAFFARNAGAR       2012  Kharif
# 47968       47968     Maharashtra             SOLAPUR       2012  Whole Year
# 37017       37017   Uttar Pradesh             SITAPUR       2012  Kharif
# ...

# %% [markdown]
# # What is the standard deviation for Area of production

# %%
df['Production'].std()
# Out:
# 13467063.590623608

# %% [markdown]
# # Which is the crop that gave the highest production to the state of Andhra Pradesh?

# %%
df.head()
# Out:
#    Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0           0       Karnataka         UDUPI       2005  Rabi
# 1           1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2           2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3           3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4           4   Uttar Pradesh     SULTANPUR       2011  Rabi
#
#          Crop    Area  Production
# 0  Horse-gram  1122.0       836.0
# 1     Brinjal   194.0         0.0
# 2     Sesamum   334.0       118.0
# 3      Tomato   538.0      7289.0
# 4   Coriander    59.0        33.0

# %%
v=df[df['State_Name']=='Andhra Pradesh']
v
# Out:
#        Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 2               2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3               3  Andhra Pradesh       KRISHNA       2014  Rabi
# 86             86  Andhra Pradesh       KURNOOL       2011  Kharif
# 126           126  Andhra Pradesh      CHITTOOR       2000  Whole Year
# 175           175  Andhra Pradesh      CHITTOOR       2007  Kharif
# ...           ...             ...           ...        ...          ...
# 73681       73681  Andhra Pradesh  SPSR NELLORE       2006  Whole Year
# 73713       73713  Andhra Pradesh       KRISHNA       2005  Kharif
# 73787       73787  Andhra Pradesh      PRAKASAM       2006  Rabi
# 73805       73805  Andhra Pradesh       KRISHNA       2012  Rabi
# 73826       73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 2                Sesamum     334.0       118.0
# 3                 Tomato     538.0      7289.0
# ...

# %%
v.groupby(['District_Name'])['Production'].max().sort_values(ascending=False).reset_index()
# Out:
#      District_Name   Production
# 0    EAST GODAVARI  780162000.0
# 1    WEST GODAVARI  289443441.0
# 2   VISAKHAPATANAM  160779000.0
# 3       SRIKAKULAM   99616798.0
# 4     VIZIANAGARAM   43592000.0
# 5          KRISHNA   34309000.0
# 6         CHITTOOR   29376960.0
# 7     SPSR NELLORE   12558000.0
# 8        ANANTAPUR    7165320.0
# 9           GUNTUR    5555550.0
# 10        PRAKASAM    2369640.0
# 11         KURNOOL     809620.0
# 12          KADAPA     488607.0

# %%
v.groupby(['Crop'])['Production'].max().sort_values(ascending=False).reset_index()
# Out:
#                  Crop   Production
# 0            Coconut   780162000.0
# 1           Sugarcane    3697441.0
# 2                Rice    1624324.0
# 3               Maize     950884.0
# 4        Cotton(lint)     809620.0
# ..                ...          ...
# 62           Cucumber          0.0
# 63       Bottle Gourd          0.0
# 64   Other Vegetables          0.0
# 65       other fibres          0.0
# 66  Peas  (vegetable)          0.0
#
# [67 rows x 2 columns]

# %% [markdown]
# # Which of the following statements is true? (Select all that applies)
# a. The overall production during the Kharif season is 2,029,970,000 (approx.)
# b. The overall production during the Summer season is 51,992,900 (approx.)
# c. The overall production during the Autumn season is 14,413,770 (approx.)
# d. The overall production during the Kharif season is 1,282,056,700 (approx.)

# %%
df.head()
# Out:
#    Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0           0       Karnataka         UDUPI       2005  Rabi
# 1           1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2           2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3           3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4           4   Uttar Pradesh     SULTANPUR       2011  Rabi
#
#          Crop    Area  Production
# 0  Horse-gram  1122.0       836.0
# 1     Brinjal   194.0         0.0
# 2     Sesamum   334.0       118.0
# 3      Tomato   538.0      7289.0
# 4   Coriander    59.0        33.0

# %%
df.groupby(['Season'])['Production'].max().reset_index()
# Out:
#         Season    Production
# 0  Autumn       2.573210e+05
# 1  Kharif       1.520591e+07
# 2  Rabi         3.506137e+06
# 3  Summer       8.822890e+05
# 4  Whole Year   1.001000e+09
# 5  Winter       1.841788e+06

# %%
sns.barplot(df['Season'],df['Production'], data=df)
# Out:
# <AxesSubplot:xlabel='Season', ylabel='Production'>

# %% [markdown]
# # Which state has the lowest area of production

# %%
df.head(2)
# Out:
#    Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0           0       Karnataka         UDUPI       2005  Rabi
# 1           1  Madhya Pradesh       GWALIOR       2003  Whole Year
#
#          Crop    Area  Production
# 0  Horse-gram  1122.0       836.0
# 1     Brinjal   194.0         0.0

# %%
 df.groupby(['State_Name'])['Area'].sum().sort_values()
# Out:
# State_Name
# Chandigarh                     2.791000e+03
# Andaman and Nicobar Islands    8.531894e+04
# Dadra and Nagar Haveli         1.182820e+05
# Puducherry                     1.206340e+05
# Goa                            2.702040e+05
# Mizoram                        2.711313e+05
# Sikkim                         3.922050e+05
# Manipur                        6.121800e+05
# Meghalaya                      1.270237e+06
# Arunachal Pradesh              1.283609e+06
# Tripura                        1.605874e+06
# Nagaland                       1.800631e+06
# Jammu and Kashmir              2.744164e+06
# Jharkhand                      2.748473e+06
# Himachal Pradesh               2.897344e+06
# Uttarakhand                    5.714422e+06
# Kerala                         8.871677e+06
# Assam                          2.065623e+07
# Telangana                      2.225371e+07
# Chhattisgarh                   2.547540e+07
# Haryana                        2.756965e+07
# ...

# %%
df['Area'].mean()
# Out:
# 12035.385977242398

# %%
#q11

# %%
df
# Out:
#        Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0               0       Karnataka         UDUPI       2005  Rabi
# 1               1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2               2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3               3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4               4   Uttar Pradesh     SULTANPUR       2011  Rabi
# ...           ...             ...           ...        ...          ...
# 73822       73822   Uttar Pradesh     SULTANPUR       2001  Rabi
# 73823       73823    Chhattisgarh          DURG       2014  Rabi
# 73824       73824   Uttar Pradesh    RAE BARELI       2010  Summer
# 73825       73825           Assam        KAMRUP       1998  Rabi
# 73826       73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 0             Horse-gram    1122.0       836.0
# 1                Brinjal     194.0         0.0
# ...
